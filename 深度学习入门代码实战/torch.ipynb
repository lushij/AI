# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
batch_size = 2
src_len=torch.randint(5,15,(batch_size,))#(batch_size,): 指定生成张量（Tensor）的形状。这里是 (2,)，即一个包含 2 个元素的一维向量。
print(src_len.shape)
print(src_len)
# Out:
# torch.Size([2])
# tensor([5, 8])
